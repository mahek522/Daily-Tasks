# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {'Hours Studies' : [2, 5, 4, 4, 3, 6, 3, 5, 2, 3, 4, 5] , 'Score' : [67, 83, 78, 77, 68, 90, 70, 84, 65, 69, 77, 88]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Hours Studies  Score
# 0               2     67
# 1               5     83
# 2               4     78
# 3               4     77
# 4               3     68
# 5               6     90
# 6               3     70
# 7               5     84
# 8               2     65
# 9               3     69
# 10              4     77
# 11              5     88

# %%
plt.scatter(df['Hours Studies'], df['Score'])
plt.show()
