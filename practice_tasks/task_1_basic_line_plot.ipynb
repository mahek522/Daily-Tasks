# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
days = {"Days": [1, 2, 3, 4, 5, 6, 7]}

# %%
data = {"Days": [1, 2, 3, 4, 5, 6, 7], "Sales": [100, 302, 403, 300, 200, 500, 116]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Days  Sales
# 0     1    100
# 1     2    302
# 2     3    403
# 3     4    300
# 4     5    200
# 5     6    500
# 6     7    116

# %%
plt.plot(df)
